# %% [markdown]
# 1. Importar las librerías necesarias para crear la conexión y trabajar con Pandas.

# %%
import mysql.connector 
from mysql.connector import Error

# %% [markdown]
# 2. Crear la conexión a la base de datos Northwind que devuelva un mensaje de error si algo no ocurre cómo debería.

# %%
try:
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='AlumnaAdalab',
        database='northwind'
    )
    print('Conexión exitosa')
except Error as e:
    print('Error al conectar:', e)
# Out:
# Conexión exitosa

# %% [markdown]
# 3. Usando "information_schema" en la conexión a base de datos, extraer los nombres de las columnas de la tabla "customers" de la bases de datos "northwind".

# %%
cursor = connection.cursor()
query1 = "SELECT CompanyName FROM customers"

cursor.execute(query1)
query1_result=cursor.fetchall()

print(query1_result)
# Out:
# [('Alfreds Futterkiste',), ('Ana Trujillo Emparedados y helados',), ('Antonio Moreno Taquera',), ('Around the Horn',), ("B's Beverages",), ('Berglunds snabbkp',), ('Blauer See Delikatessen',), ('Blido Comidas preparadas',), ('Blondesddsl pre et fils',), ("Bon app'",), ('Bottom-Dollar Markets',), ('Cactus Comidas para llevar',), ('Centro comercial Moctezuma',), ('Chop-suey Chinese',), ('Comrcio Mineiro',), ('Consolidated Holdings',), ('Die Wandernde Kuh',), ('Drachenblut Delikatessen',), ('Du monde entier',), ('Eastern Connection',), ('Ernst Handel',), ('Familia Arquibaldo',), ('FISSA Fabrica Inter. Salchichas S.A.',), ('Folies gourmandes',), ('Folk och f HB',), ('France restauration',), ('Franchi S.p.A.',), ('Frankenversand',), ('Furia Bacalhau e Frutos do Mar',), ('Galera del gastrnomo',), ('Godos Cocina Tpica',), ('Gourmet Lanchonetes',), ('Great Lakes Food Market',), ('GROSELLA-Restaurante',), ('Hanari Carnes',), ('HILARION-Abastos',), ('Hungry Coyote Import Store',), ('Hungry Owl All-Night Grocers',), ('Island Trading',), ('IT',), ('IT',), ('Kniglich Essen',), ("La corne d'abondance",), ("La maison d'Asie",), ('Laughing Bacchus Wine Cellars',), ('Lazy K Kountry Store',), ('Lehmanns Marktstand',), ("Let's Stop N Shop",), ('LILA-Supermercado',), ('LINO-Delicateses',), ('Lonesome Pine Restaurant',), ('Magazzini Alimentari Riuniti',), ('Maison Dewey',), ('Morgenstern Gesundkost',), ('Mre Paillarde',), ('North/South',), ('Ocano Atlntico Ltda.',), ('Old World Delicatessen',), ('Ottilies Kseladen',), ('Paris spcialits',), ('Pericles Comidas clsicas',), ('Piccolo und mehr',), ('Princesa Isabel Vinhos',), ('Que Delcia',), ('Queen Cozinha',), ('QUICK-Stop',), ('Rancho grande',), ('Rattlesnake Canyon Grocery',), ('Reggiani Caseifici',), ('Ricardo Adocicados',), ('Richter Supermarkt',), ('Romero y tomillo',), ('Sant Gourmet',), ('Save-a-lot Markets',), ('Seven Seas Imports',), ('Simons bistro',), ('Spcialits du monde',), ('Split Rail Beer & Ale',), ('Suprmes dlices',), ('The Big Cheese',), ('The Cracker Box',), ('Toms Spezialitten',), ('Tortuga Restaurante',), ('Tradio Hipermercados',), ("Trail's Head Gourmet Provisioners",), ('Vaffeljernet',), ('Victuailles en stock',), ('Vins et alcools Chevalier',), ('Wartian Herkku',), ('Wellington Importadora',), ('White Clover Markets',), ('Wilman Kala',), ('Wolski  Zajazd',)]

# %% [markdown]
# 4. Seleccionar todo de la tabla "customers" donde "city" sea "London" o "Seattle". Almacenar los resultados en una variable.

# %%
query4 = "SELECT * FROM customers Where City IN ('London', 'Seattle')"
cursor.execute(query4)
query4_result=cursor.fetchall()
print(query4_result)
# Out:
# [('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None), ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'), ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'), ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'), ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'), ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115')]

# %% [markdown]
# 5. Convertir los resultados del ejercicio anterior en un Dataframe (no olvidéis de poner el nombre a las columnas en el orden correcto).

# %%
import pandas as pd

df_query4 = pd.read_sql("SELECT * FROM customers Where City IN ('London', 'Seattle')", connection)
df_query4
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13492\1829056672.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_query4 = pd.read_sql("SELECT * FROM customers Where City IN ('London', 'Seattle')", connection)
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6      WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         Address     City Region PostalCode Country  \
# 0               120 Hanover Sq.   London   None    WA1 1DP      UK
# 1             Fauntleroy Circus   London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London   None    WX1 6LT      UK
# 3                35 King George   London   None    WX3 6FW      UK
# 4  South House 300 Queensbridge   London   None    SW7 1RZ      UK
# 5               90 Wadhurst Rd.   London   None   OX15 4NB      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA      98128     USA
#
#             Phone             Fax
# 0  (171) 555-7788  (171) 555-6750
# 1  (171) 555-1212            None
# 2  (171) 555-2282  (171) 555-9199
# 3  (171) 555-0297  (171) 555-3373
# 4  (171) 555-7733  (171) 555-2530
# 5  (171) 555-1717  (171) 555-5646
# 6  (206) 555-4112  (206) 555-4115

# %% [markdown]
# 6. Muestra las 10 primeras filas del Dataframe y las 10 últimas.

# %% [markdown]
# 7. Mostrar 5 filas aleatorias del Dataframe.

# %% [markdown]
# 8. ¿Hay nulos en el Dataframe? El resultado debe verse para cada una de las columnas.

# %% [markdown]
# 9. Mostrar los principales estadísticos.

# %% [markdown]
# 10. Mostrar el nombre de las columnas del Dataframe.
