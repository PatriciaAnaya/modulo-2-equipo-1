# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
driver = webdriver.Firefox()
driver.get("https://www.casadellibro.com/")
sleep(5)
driver.find_element("css selector","#onetrust-reject-all-handler").click()
sleep(2)
driver.find_element("css selector","div.link-menu:nth-child(3) > a:nth-child(1)").click()
diccionario_resultados = {"Titulo": [], "Autor(es)":[], "Precio" : [], "Editorial" : [], "Idioma" : [], "Número páginas": [] }

for libro in range(1,5):
    sleep(5)
    driver.find_element("css selector", f"cma-component.svelte-f3gp65:nth-child(3) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1) > div:nth-child({libro}) > div:nth-child(8) > div:nth-child(1) > a:nth-child(1))").click()
    sleep(5)
    Titulo = driver.find_element("css selector", "#t-p-f").text
    diccionario_resultados["Titulo"].append(Titulo)

    Autor = driver.find_element("css selector", "#a-p-f > p:nth-child(1) > a:nth-child(1)").text
    diccionario_resultados["Autor"].append(Autor)

    Precio = driver.find_element("css selector", "#p-pf-f").text
    diccionario_resultados["Precio"].append(Precio)

    Editorial = driver.find_element("css selector", "h3.campo:nth-child(1)").text
    diccionario_resultados["Editorial"].append(Editorial)

    Idioma = driver.find_element("css selector", "h3.campo:nth-child(3)").text
    diccionario_resultados["Idioma"].append(Idioma)

    Num_paginas = driver.find_element("css selector", "div.campo:nth-child(4)").text
    diccionario_resultados["Número páginas"].append(Num_paginas)
    
    driver.back()
    sleep(5)
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[10], line 11
#       9 for libro in range(1,5):
#      10     sleep(5)
# ---> 11     driver.find_element("css selector", f"cma-component.svelte-f3gp65:nth-child(3) > div:nth-child(1) > div:nth-child(3) > div:nth-child(1) > div:nth-child({libro}) > div:nth-child(8) > div:nth-child(1) > a:nth-child(1))").click()
#      12     sleep(5)
#      13     Titulo = driver.find_element("css selector", "#t-p-f").text
#
# File c:\Users\User\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...
