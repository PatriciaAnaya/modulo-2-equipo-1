# %% [markdown]
# 1. Hacer las importaciones necesarias para abrir un archivo de tipo csv en Pandas.

# %%
import pandas as pd

# %% [markdown]
# 2. Abrir el archivo, creando un dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
videogames = pd.read_csv("./Ficheros/videogames.csv")
videogames_updated = videogames.drop(columns=["Unnamed: 0"])

videogames_updated
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# 3. Guardar el dataframe en formato Excel y después crear un dataframe con el Excel. ¿El dataframe es similar al que teníais antes?

# %%
videogames_updated.to_excel("videogames_updated.xlsx", index=False)

# %%
videogames_excel = pd.read_excel("videogames_updated.xlsx")
videogames_excel
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
videogames_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.3+ MB

# %%
videogames_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# 4. Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv .

# %%
videogames_csv = videogames_excel.to_csv("./Files/videogames_updated.xlsx")
# Si hay que crear un archivo en una localización específica, se debe indicar la ruta completa al guardarlo (donde indicas el nombre)

# %% [markdown]
# 5. Copia el archivo personal.json en la carpeta Files.

# %% [markdown]
# 6. Abre el fichero json (con el json.load(f)) y haz las modificaciones necesarias para que tenga formato de tabla (Para esto necesitas normalizar los datos con el pd.json_normalize).

# %%
import json
import pandas as pd

with open('./Files/personal.json', 'r', encoding='utf-8') as f:
    datos = json.load(f)

# Normalizar los datos
df_personal = pd.json_normalize(datos["workers"]) 
#se debe especificar la clave principal del JSON, que en este caso sería "workers"

# %%
df_personal_modificado = df_personal.to_json("./Files/personal_modificado.json")

# %% [markdown]
# 7. Guardar el json modificado y abrirlo en Pandas.¿Cómo queda ahora?

# %%
df_personal
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
