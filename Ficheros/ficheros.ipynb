# %%
import pandas as pd

# %%
variable=pd.read_csv("./modulo-2-equipo-1")
variable= pd.read_excel("ruta_donde_esta _el_fichero")
variable= pd.read_json("ruta_donde_esta _el_fichero")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 variable=pd.read_csv("./modulo-2-equipo-1")
#       2 variable= pd.read_excel("ruta_donde_esta _el_fichero")
#       3 variable= pd.read_json("ruta_donde_esta _el_fichero")
#
# ...

# %%
## leer un json

df_one_piece=pd.read_json("./one_piece.json")

# %%
df_one_piece
# Out:
#      rank  trend  season  episode  \
# 0  24,129     18       1        1
# 1  29,290     11       1        2
# 2  32,043      7       1        3
# 3  28,818      8       1        4
# 4  37,113      4       1        5
# 5  36,209      4       1        6
#
#                                                 name  start  total_votes  \
# 0  I'm Luffy! The Man Who Will Become the Pirate ...   1999          647
# 1  The Great Swordsman Appears! Pirate Hunter, Ro...   1999          473
# 2  Morgan vs. Luffy! Who's This Beautiful Young G...   1999          428
# 3       Luffy's Past! The Red-haired Shanks Appears!   1999          449
# 4  Fear, Mysterious Power! Pirate Clown Captain B...   1999          370
# 5  Desperate Situation! Beast Tamer Mohji vs. Luffy!   1999          364
#
#    average_rating
# 0             7.6
# 1             7.8
# 2             7.7
# 3             8.1
# 4             7.5
# 5             7.7

# %%
df_one_piece.tail(3)
# Out:
#      rank  trend  season  episode  \
# 3  28,818      8       1        4
# 4  37,113      4       1        5
# 5  36,209      4       1        6
#
#                                                 name  start  total_votes  \
# 3       Luffy's Past! The Red-haired Shanks Appears!   1999          449
# 4  Fear, Mysterious Power! Pirate Clown Captain B...   1999          370
# 5  Desperate Situation! Beast Tamer Mohji vs. Luffy!   1999          364
#
#    average_rating
# 3             8.1
# 4             7.5
# 5             7.7

# %%
df_one_piece.columns
# Out:
# Index(['rank', 'trend', 'season', 'episode', 'name', 'start', 'total_votes',
#        'average_rating'],
#       dtype='object')

# %%
books=pd.read_xml("./books.xml",parser="etree")

# %%
books
# Out:
#        id                author                                   title  \
# 0   bk101  Gambardella, Matthew                   XML Developer's Guide
# 1   bk102            Ralls, Kim                           Midnight Rain
# 2   bk103           Corets, Eva                         Maeve Ascendant
# 3   bk104           Corets, Eva                         Oberon's Legacy
# 4   bk105           Corets, Eva                      The Sundered Grail
# 5   bk106      Randall, Cynthia                             Lover Birds
# 6   bk107        Thurman, Paula                           Splish Splash
# 7   bk108         Knorr, Stefan                         Creepy Crawlies
# 8   bk109          Kress, Peter                            Paradox Lost
# 9   bk110          O'Brien, Tim   Microsoft .NET: The Programming Bible
# 10  bk111          O'Brien, Tim           MSXML3: A Comprehensive Guide
# 11  bk112           Galos, Mike  Visual Studio 7: A Comprehensive Guide
#
# ...

# %%
## leer excel
df_libros= pd.read_excel("./libros_ejemplo.xlsx")

# %%
df_clientes=pd.read_csv("./clientes.csv")

# %%
df_clientes
# Out:
#                                                     id  first_name last_name  \
# 0                                                    1       Cheri  Dunsmore
# 1                                                    2        Hunt  Bartomeu
# 2                                                    3  Michaeline   Paynton
# 3                                                    4      Filmer    Eirwin
# 4    5,Tanhya,Lubbock,tlubbock4@huffingtonpost.com,...         NaN       NaN
# ..                                                 ...         ...       ...
# 995                                                996         Ray    Tarpey
# 996                                                997        Flem  Roderham
# 997                                                998   Winifield    Blakes
# 998                                                999      Lanita  Espinosa
# 999                                               1000     Grissel   Siberry
#
# ...

# %%
df_clientes.isnull().sum()
# Out:
# id              0
# first_name     52
# last_name      52
# email          77
# gender        123
# City          176
# Country       200
# Address        91
# dtype: int64

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   object
#  1   first_name  948 non-null    object
#  2   last_name   948 non-null    object
#  3   email       923 non-null    object
#  4   gender      877 non-null    object
#  5   City        824 non-null    object
#  6   Country     800 non-null    object
#  7   Address     909 non-null    object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df_christmas=pd.read_csv("./christmas_movies.csv")

# %% [markdown]
# ## CONECTAR SQL
#
# # conectar son SQL
# # crear BD
# # Insertar
# #realizar consultas a BD

# %%
import mysql.connector
from mysql.connector import Error

try:
    cnx=connection = mysql.connector.connect(
        host='127.0.0.1',
        user='root',
        password='?10101948SanMartin',
        
    )
    print('Conexión exitosa')
except Error as e:
    print('Error al conectar:', e)
# Out:
# Conexión exitosa

# %% [markdown]
# ## crear BD

# %%
try:
    mycursor = cnx.cursor()
    query = "CREATE DATABASE IF NOT EXISTS christmas"
    mycursor.execute(query)
    print("Query exitosa")
except:
    print("Error.")
# Out:
# Query exitosa

# %% [markdown]
# # crear tabla

# %%
mycursor.execute("USE christmas")

query = '''CREATE TABLE christmas_movies (
    id INT PRIMARY KEY AUTO_INCREMENT,
    title VARCHAR(255) NOT NULL,
    rating VARCHAR(20),
    runtime INT,
    imdb_rating DECIMAL(3,1),
    meta_score INT,
    genre VARCHAR(255),
    release_year INT,
    description TEXT,
    director VARCHAR(255),
    stars TEXT,
    votes VARCHAR(50),
    gross VARCHAR(50),
    img_src VARCHAR(500),
    type VARCHAR(50)
);'''

mycursor.execute(query)

# %%
import numpy as np

# 3. Insertar
# Query de inserción
query_insert = """
INSERT INTO christmas_movies (title, rating, runtime, imdb_rating, meta_score, 
                              genre, release_year, description, director, stars, 
                              votes, gross, img_src, type) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

df_clean = df_christmas.replace({np.nan: None, 'nan': None, 'NaN': None})

datos = df_clean.values.tolist()

# Ejecutar inserción
mycursor.executemany(query_insert, datos)
cnx.commit()

print(f"{mycursor.rowcount} registros insertados")

print(f"{mycursor.rowcount} registros insertados")
# Out:
# 873 registros insertados
# 873 registros insertados
